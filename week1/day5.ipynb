# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/mistralai/Magistral-Small-2506',
#  '/openbmb/MiniCPM4-8B',
#  '/Qwen/Qwen3-Embedding-0.6B-GGUF',
#  '/deepseek-ai/DeepSeek-R1-0528',
#  '/fishaudio/openaudio-s1-mini',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/ResembleAI/Chatterbox',
#  '/spaces/multimodalart/wan2-1-fast',
#  '/spaces/aisheets/sheets',
#  '/spaces/NihalGazi/Text-To-Speech-Unlimited',
#  '/spaces',
#  '/datasets/nvidia/Nemotron-Personas',
#  '/datasets/open-thoughts/OpenThoughts3-1.2M',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/a-m-team/AM-DeepSeek-R1-0528-Distilled',
#  '/datasets/institutional/institutional-books-1.0',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'company page',
#    'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'forum/discussion page', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussion page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# mistralai/Magistral-Small-2506
# Updated
# 2 days ago
# •
# 5.82k
# •
# 362
# openbmb/MiniCPM4-8B
# Updated
# about 8 hours ago
# •
# 3.06k
# •
# 217
# Qwen/Qwen3-Embedding-0.6B-GGUF
# Updated
# 4 days ago
# •
# 14.8k
# •
# 345
# deepseek-ai/DeepSeek-R1-0528
# Updated
# 15 days ago
# •
# 116k
# •
# 1.95k
# fishaudio/openaudio-s1-mini
# Updated
# 10 days ago
# •
# 2.38k
# •
# 251
# Browse 1M+ models
# Spaces
# Running
# 7.99k
# 7.99k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 1.04k
# 1.04k
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# Running
# on
# Zero
# 669
# 669
# Wan2.1 Fast
# 🎥
# Turn static images into animated videos
# Running
# 153
# 153
# Sheets
# 🗂
# Convert ideas into structured datasets
# Running
# 537
# 537
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# Browse 400k+ applications
# Datasets
# nvidia/Nemotron-Personas
# Updated
# 4 days ago
# •
# 4.12k
# •
# 76
# open-thoughts/OpenThoughts3-1.2M
# Updated
# 4 days ago
# •
# 11k
# •
# 99
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 22.5k
# •
# 7.91k
# a-m-team/AM-DeepSeek-R1-0528-Distilled
# Updated
# 4 days ago
# •
# 4.83k
# •
# 64
# institutional/institutional-books-1.0
# Updated
# 1 day ago
# •
# 423
# •
# 27
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 765 models
# •
# 3.42k followers
# AI at Meta
# Enterprise
# company
# •
# 2.16k models
# •
# 6.41k followers
# Amazon
# company
# •
# 20 models
# •
# 3.23k followers
# Google
# company
# •
# 999 models
# •
# 16.5k followers
# Intel
# company
# •
# 232 models
# •
# 2.63k followers
# Microsoft
# company
# •
# 390 models
# •
# 12.9k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 162 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 297 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 145,550
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,340
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,304
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,682
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,793
# Fast tokenizers optimized for research & production
# TRL
# 14,157
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,796
# State-of-the-art ML running directly in your browser
# smolagents
# 20,093
# Smol library to build great agents in Python
# PEFT
# 18,756
# Parameter-efficient finetuning for large language models
# Datasets
# 20,266
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,216
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,826
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 43,149
# AI & ML interests
# The AI community building the future.
# Recent Activity
# aractingi
# new
# activity
# 28 minutes ago
# huggingface/documentation-images:
# intervention_image_tutorial
# aractingi
# new
# activity
# about 1 hour ago
# huggingface/documentation-images:
# So101_tutorial_vid
# cfahlgren1
# new
# activity
# about 18 hours ago
# huggingface/InferenceSupport:
# mistralai/Devstral-Small-2505
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 46
# Team members
# 215
# +181
# +168
# +147
# +137
# +117
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 249k
# •
# •
# 48
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 11.9M
# •
# •
# 707
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 3.99M
# •
# 196
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 4.64M
# •
# •
# 779
# spaces
# 28
# Sort:
# 		Recently updated
# pinned
# Running
# on
# CPU Upgrade
# 6
# Hugging Face Fast
# 🏎
# Test your internet bandwidth to Hugging Face
# huggingface
# about 20 hours ago
# pinned
# Running
# 12
# Enterprise Hub
# 🔒
# Why you need it, how to get it
# huggingface
# May 3
# pinned
# Running
# 90
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 430
# AI Deadlines
# ⚡
# Organize project deadlines with AI assistance
# huggingface
# 5 days ago
# Running
# 182
# Inference Playground
# 🔋
# Set theme of the page based on user or system preferences
# huggingface
# 16 days ago
# Running
# 9
# Space Build
# 🐨
# Generate static files for spaces
# huggingface
# 29 days ago
# Expand
# 							28
# 								spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# Updated
# 20 days ago
# •
# 4.75k
# •
# 21
# huggingface/timesfm-tourism-monthly
# Updated
# Mar 31
# •
# 23
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 51.7k
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 32
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 45.6k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 320
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 46k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 20
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 170k
# •
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand
# 							16
# 								models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# 28 minutes ago
# •
# 52
# •
# 3.19M
# •
# 69
# huggingface/label-files
# Updated
# about 22 hours ago
# •
# 1.66k
# •
# 18
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 2 days ago
# •
# 1.69k
# •
# 1.68k
# •
# 25
# huggingface/policy-docs
# Viewer
# •
# Updated
# 10 days ago
# •
# 24
# •
# 2.08k
# •
# 11
# huggingface/electricity-production
# Viewer
# •
# Updated
# 22 days ago
# •
# 397
# •
# 129
# •
# 1
# huggingface/badges
# Viewer
# •
# Updated
# Apr 8
# •
# 1
# •
# 1.69M
# •
# 45
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# Mar 15
# •
# 69
# •
# 534
# •
# 7
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 189
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 277
# huggingface/paper-central-data
# Viewer
# •
# Updated
# Jan 4
# •
# 124k
# •
# 147
# •
# 9
# Expand
# 							34
# 								datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# from $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 409 models
# •
# 28.9k followers
# Shopify
# Enterprise
# company
# •
# 477 followers
# AMD
# Enterprise
# company
# •
# 145 models
# •
# 1.59k followers
# JetBrains
# Enterprise
# company
# •
# 10 models
# •
# 557 followers
# Together
# Enterprise
# company
# •
# 33 models
# •
# 623 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 130 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 110 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 151 followers
# IBM Granite
# Enterprise
# company
# •
# 121 models
# •
# 1.87k followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 428 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 74 followers
# Skywork
# Enterprise
# company
# •
# 42 models
# •
# 723 followers
# Lightricks
# Enterprise
# company
# •
# 13 models
# •
# 1.05k followers
# Stability AI
# Enterprise
# company
# •
# 108 models
# •
# 25k followers
# Infosys Limited
# Enterprise
# company
# •
# 2 models
# •
# 863 followers
# AI at Meta
# Enterprise
# company
# •
# 2.16k models
# •
# 6.41k followers
# Snowflake
# Enterprise
# company
# •
# 23 models
# •
# 539 followers
# Arm
# Enterprise
# company
# •
# 214 followers
# Qwen
# Enterprise
# company
# •
# 289 models
# •
# 34.7k followers
# Xsolla
# Enterprise
# company
# •
# 139 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 119 followers
# Jusbrasil
# Enterprise
# company
# •
# 98 followers
# creditkarma
# Enterprise
# company
# •
# 70 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 69 followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 347 followers
# LinkedIn
# Enterprise
# company
# •
# 62 followers
# Liquid AI
# Enterprise
# company
# •
# 201 followers
# BCG X
# Enterprise
# company
# •
# 40 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 47.9k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 302 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 234 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 297 followers
# ServiceNow
# Enterprise
# company
# •
# 510 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 287 followers
# Fidelity Investments
# Enterprise
# company
# •
# 151 followers
# TNG Technology Consulting GmbH
# Enterprise
# company
# •
# 4 models
# •
# 155 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 101 models
# •
# 1.44k followers
# Chegg Inc
# Enterprise
# company
# •
# 87 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 162 followers
# MiniMax
# Enterprise
# company
# •
# 5 models
# •
# 735 followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# Novo Nordisk R&ED
# Enterprise
# company
# •
# 37 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# PRO Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# 10× Private storage capacity
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 8× more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $2.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $2.50
# 2
# 160GB
# $5.00
# 4
# 320GB
# $10.00
# 8
# 640GB
# $20.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# PRO Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get PRO
# ($9/month)
# ZeroGPU
# : Get 8× usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# models page
# Webpage Title:
# Models - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Edit Models filters
# Tasks
# Libraries
# Datasets
# Languages
# Licenses
# Other
# Multimodal
# Audio-Text-to-Text
# Image-Text-to-Text
# Visual Question Answering
# Document Question Answering
# Video-Text-to-Text
# Visual Document Retrieval
# Any-to-Any
# Computer Vision
# Depth Estimation
# Image Classification
# Object Detection
# Image Segmentation
# Text-to-Image
# Image-to-Text
# Image-to-Image
# Image-to-Video
# Unconditional Image Generation
# Video Classification
# Text-to-Video
# Zero-Shot Image Classification
# Mask Generation
# Zero-Shot Object Detection
# Text-to-3D
# Image-to-3D
# Image Feature Extraction
# Keypoint Detection
# Natural Language Processing
# Text Classification
# Token Classification
# Table Question Answering
# Question Answering
# Zero-Shot Classification
# Translation
# Summarization
# Feature Extraction
# Text Generation
# Text2Text Generation
# Fill-Mask
# Sentence Similarity
# Text Ranking
# Audio
# Text-to-Speech
# Text-to-Audio
# Automatic Speech Recognition
# Audio-to-Audio
# Audio Classification
# Voice Activity Detection
# Tabular
# Tabular Classification
# Tabular Regression
# Time Series Forecasting
# Reinforcement Learning
# Reinforcement Learning
# Robotics
# Other
# Graph Machine Learning
# Apply filters
# Models
# Full-text search
# Add filters
# Sort:
# 		Trending
# mistralai/Magistral-Small-2506
# Text Generation
# •
# Updated
# 2 days ago
# •
# 5.82k
# •
# •
# 362
# openbmb/MiniCPM4-8B
# Text Generation
# •
# Updated
# about 8 hours ago
# •
# 3.06k
# •
# 217
# Qwen/Qwen3-Embedding-0.6B-GGUF
# Updated
# 4 days ago
# •
# 14.8k
# •
# 345
# deepseek-ai/DeepSeek-R1-0528
# Text Generation
# •
# Updated
# 15 days ago
# •
# 116k
# •
# •
# 1.95k
# fishaudio/openaudio-s1-mini
# Text-to-Speech
# •
# Updated
# 10 days ago
# •
# 2.38k
# •
# 251
# echo840/MonkeyOCR
# Image-Text-to-Text
# •
# Updated
# 1 day ago
# •
# 156
# google/gemma-3n-E4B-it-litert-preview
# Image-Text-to-Text
# •
# Updated
# 18 days ago
# •
# 1.09k
# ResembleAI/chatterbox
# Text-to-Speech
# •
# Updated
# 14 days ago
# •
# •
# 775
# Qwen/Qwen3-Embedding-0.6B
# Feature Extraction
# •
# Updated
# 6 days ago
# •
# 113k
# •
# 212
# rednote-hilab/dots.llm1.inst
# Text Generation
# •
# Updated
# 2 days ago
# •
# 2.9k
# •
# 126
# Hcompany/Holo1-7B
# Image-Text-to-Text
# •
# Updated
# 3 days ago
# •
# 3.5k
# •
# 174
# black-forest-labs/FLUX.1-dev
# Text-to-Image
# •
# Updated
# Aug 16, 2024
# •
# 1.91M
# •
# •
# 10.5k
# open-thoughts/OpenThinker3-7B
# Text Generation
# •
# Updated
# 4 days ago
# •
# 5.87k
# •
# •
# 104
# Qwen/Qwen3-Embedding-8B
# Feature Extraction
# •
# Updated
# 6 days ago
# •
# 16.9k
# •
# •
# 128
# lerobot/smolvla_base
# Robotics
# •
# Updated
# 2 days ago
# •
# 5.04k
# •
# 157
# Qwen/Qwen3-Reranker-0.6B
# Text Ranking
# •
# Updated
# 4 days ago
# •
# 18.7k
# •
# 110
# fluxions/vui
# Text-to-Speech
# •
# Updated
# 3 days ago
# •
# 97
# nanonets/Nanonets-OCR-s
# Image-Text-to-Text
# •
# Updated
# about 24 hours ago
# •
# 88
# •
# 70
# facebook/vjepa2-vitl-fpc64-256
# Video Classification
# •
# Updated
# 2 days ago
# •
# 477
# •
# 66
# lodestones/Chroma
# Text-to-Image
# •
# Updated
# 2 days ago
# •
# 829
# deepseek-ai/DeepSeek-R1-0528-Qwen3-8B
# Text Generation
# •
# Updated
# 15 days ago
# •
# 248k
# •
# •
# 736
# unsloth/Magistral-Small-2506-GGUF
# Text2Text Generation
# •
# Updated
# 2 days ago
# •
# 12.3k
# •
# 59
# osmosis-ai/Osmosis-Structure-0.6B
# Updated
# 4 days ago
# •
# 1.47k
# •
# 327
# Qwen/Qwen3-Reranker-8B
# Text Ranking
# •
# Updated
# 4 days ago
# •
# 5.15k
# •
# 91
# BAAI/RoboBrain2.0-7B
# Robotics
# •
# Updated
# 3 days ago
# •
# 514
# •
# 57
# CEIA-UFG/Gemma-3-Gaia-PT-BR-4b-it
# Image-Text-to-Text
# •
# Updated
# 3 days ago
# •
# 1.07k
# •
# 51
# tencent/HunyuanVideo-Avatar
# Image-to-Video
# •
# Updated
# 16 days ago
# •
# 194
# google/gemma-3n-E2B-it-litert-preview
# Image-Text-to-Text
# •
# Updated
# 24 days ago
# •
# 366
# mistralai/Magistral-Small-2506_gguf
# Text2Text Generation
# •
# Updated
# 3 days ago
# •
# 1.81k
# •
# 49
# rednote-hilab/dots.llm1.base
# Text Generation
# •
# Updated
# 3 days ago
# •
# 872
# •
# 51
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# datasets page
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Edit Datasets filters
# Main
# Tasks
# Libraries
# Languages
# Licenses
# Other
# Modalities
# 3D
# Audio
# Document
# Geospatial
# Image
# Tabular
# Text
# Time-series
# Video
# Size
# 			(rows)
# Reset Size
# < 1K
# > 1T
# Format
# json
# csv
# parquet
# imagefolder
# soundfolder
# webdataset
# text
# arrow
# Apply filters
# Datasets
# 421,354
# Full-text search
# Add filters
# Sort:
# 		Trending
# nvidia/Nemotron-Personas
# Viewer
# •
# Updated
# 4 days ago
# •
# 100k
# •
# 4.12k
# •
# 76
# open-thoughts/OpenThoughts3-1.2M
# Viewer
# •
# Updated
# 4 days ago
# •
# 1.2M
# •
# 11k
# •
# 99
# fka/awesome-chatgpt-prompts
# Viewer
# •
# Updated
# Jan 6
# •
# 203
# •
# 22.5k
# •
# 7.91k
# a-m-team/AM-DeepSeek-R1-0528-Distilled
# Preview
# •
# Updated
# 4 days ago
# •
# 4.83k
# •
# 64
# institutional/institutional-books-1.0
# Viewer
# •
# Updated
# 1 day ago
# •
# 983k
# •
# 423
# •
# 27
# miriad/miriad-5.8M
# Viewer
# •
# Updated
# 1 day ago
# •
# 5.82M
# •
# 888
# •
# 25
# openbmb/Ultra-FineWeb
# Viewer
# •
# Updated
# 7 days ago
# •
# 1.29B
# •
# 42.1k
# •
# 164
# yandex/yambda
# Viewer
# •
# Updated
# 7 days ago
# •
# 5.31B
# •
# 46.1k
# •
# 157
# common-pile/comma_v0.1_training_dataset
# Viewer
# •
# Updated
# 7 days ago
# •
# 784M
# •
# 9.21k
# •
# 27
# open-r1/Mixture-of-Thoughts
# Viewer
# •
# Updated
# 18 days ago
# •
# 699k
# •
# 33.3k
# •
# 213
# Hcompany/WebClick
# Viewer
# •
# Updated
# 4 days ago
# •
# 1.64k
# •
# 5.79k
# •
# 49
# Dataseeds/DataSeeds.AI-Sample-Dataset-DSD
# Viewer
# •
# Updated
# 2 days ago
# •
# 7.77k
# •
# 726
# •
# 17
# PleIAs/common_corpus
# Viewer
# •
# Updated
# 3 days ago
# •
# 470M
# •
# 251k
# •
# 286
# DeepMount00/italian_conversations
# Viewer
# •
# Updated
# 2 days ago
# •
# 1k
# •
# 91
# •
# 13
# Josephgflowers/Finance-Instruct-500k
# Viewer
# •
# Updated
# Mar 1
# •
# 518k
# •
# 1.14k
# •
# 82
# thivux/phoaudiobook
# Viewer
# •
# Updated
# 2 days ago
# •
# 1.04M
# •
# 1.77k
# •
# 12
# HuggingFaceFW/fineweb-edu
# Viewer
# •
# Updated
# Jan 31
# •
# 3.3B
# •
# 133k
# •
# 695
# AlicanKiraz0/All-CVE-Records-Training-Dataset
# Viewer
# •
# Updated
# about 20 hours ago
# •
# 297k
# •
# 85
# •
# 10
# Anthropic/hh-rlhf
# Viewer
# •
# Updated
# May 26, 2023
# •
# 169k
# •
# 10.9k
# •
# 1.35k
# HuggingFaceFW/fineweb
# Viewer
# •
# Updated
# Jan 31
# •
# 25B
# •
# 356k
# •
# 2.19k
# FreedomIntelligence/medical-o1-reasoning-SFT
# Viewer
# •
# Updated
# Apr 22
# •
# 90.1k
# •
# 11.1k
# •
# 745
# Mxode/Chinese-Instruct
# Viewer
# •
# Updated
# May 9
# •
# 4.85M
# •
# 2.33k
# •
# 35
# miriad/miriad-4.4M
# Viewer
# •
# Updated
# 1 day ago
# •
# 4.49M
# •
# 254
# •
# 9
# zou-lab/MedCaseReasoning
# Viewer
# •
# Updated
# 11 days ago
# •
# 14.5k
# •
# 607
# •
# 14
# IGNF/FLAIR-HUB
# Updated
# 3 days ago
# •
# 1.41k
# •
# 9
# openai/gsm8k
# Viewer
# •
# Updated
# Jan 4, 2024
# •
# 17.6k
# •
# 500k
# •
# 761
# roneneldan/TinyStories
# Viewer
# •
# Updated
# Aug 12, 2024
# •
# 2.14M
# •
# 25.5k
# •
# 680
# nvidia/hifitts-2
# Viewer
# •
# Updated
# about 6 hours ago
# •
# 16.6M
# •
# 184
# •
# 10
# microsoft/mediflow
# Viewer
# •
# Updated
# 14 days ago
# •
# 1.84M
# •
# 3.42k
# •
# 33
# Trendyol/All-CVE-Chat-MultiTurn-1999-2025-Dataset
# Viewer
# •
# Updated
# about 22 hours ago
# •
# 297k
# •
# 8
# Previous
# 1
# 2
# 3
# ...
# 100
# Next
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# spaces page
# Webpage Title:
# Spaces - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Spaces
# ·
# The AI App Directory
# New Space
# Get PRO
# Learn more
# Image Generation
# Video Generation
# Text Generation
# Language Translation
# Speech Synthesis
# 3D Modeling
# Object Detection
# Text Analysis
# Image Editing
# Code Generation
# Question Answering
# Data Visualization
# Voice Cloning
# Background Removal
# Image Upscaling
# OCR
# Document Analysis
# Visual QA
# Image Captioning
# Chatbots
# Sentiment Analysis
# Text Summarization
# Music Generation
# Medical Imaging
# Financial Analysis
# Game AI
# Model Benchmarking
# Fine Tuning Tools
# Dataset Creation
# Pose Estimation
# Face Recognition
# Anomaly Detection
# Recommendation Systems
# Character Animation
# Style Transfer
# Image
# Spaces of the week
# 9 Jun 2025
# Filters
# (0)
# Sort:
# 		Relevance
# Running
# 163
# Conversational WebGPU
# 🚀
# webml-community
# 9 days ago
# Running
# 101
# Dots Demo
# 💻
# Generate responses to text inputs
# rednote-hilab
# 7 days ago
# Running
# 125
# Graphify
# ⚡
# Create multiple diagram types instantly from JSON!
# Agents-MCP-Hackathon
# 2 days ago
# Running
# on
# Zero
# 34
# Holo1 Navigation
# 🐠
# Web Navigation powered by Holo1 Vision-Language Action Model
# Hcompany
# 9 days ago
# Running
# on
# Zero
# 79
# Vui
# 🏢
# NotebookLM conversational speech model
# fluxions
# 7 days ago
# Running
# on
# Zero
# 49
# CapSpeech TTS
# 🧢
# Stylized TTS – design voice, accent, and emotion your way
# OpenSound
# 8 days ago
# Running
# on
# Zero
# 23
# Solving Inverse Problems with FLAIR
# 🎨
# Restore and enhance images using text prompts
# prs-eth
# 9 days ago
# Running
# 20
# Qwen3 Embedding WebGPU
# 📚
# Generate a scatterplot to visualize sentence categories
# webml-community
# 7 days ago
# All running apps, trending first
# Running
# 7.99k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# enzostvs
# 2 days ago
# Running
# on
# Zero
# 1.04k
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# ResembleAI
# 15 days ago
# Running
# on
# Zero
# 669
# Wan2.1 Fast
# 🎥
# Turn static images into animated videos
# multimodalart
# 22 days ago
# Running
# 153
# Sheets
# 🗂
# Convert ideas into structured datasets
# aisheets
# 3 days ago
# Running
# 537
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# NihalGazi
# 9 days ago
# Running
# 128
# AI Marketing Content Generator
# 🎨
# An AI-powered tool made for content creators and marketers
# Agents-MCP-Hackathon
# 3 days ago
# Running
# 125
# Graphify
# ⚡
# Create multiple diagram types instantly from JSON!
# Agents-MCP-Hackathon
# 2 days ago
# Running
# 101
# Dots Demo
# 💻
# Generate responses to text inputs
# rednote-hilab
# 7 days ago
# Running
# on
# Zero
# 766
# LTX Video Fast
# 🎥
# ultra-fast video model, LTX 0.9.7 13B distilled
# Lightricks
# 3 days ago
# Running
# on
# Zero
# 79
# Vui
# 🏢
# NotebookLM conversational speech model
# fluxions
# 7 days ago
# Running
# on
# Zero
# 258
# Chain-of-Zoom
# 🚀
# Extreme Super-Resolution via Scale Autoregression
# alexnasa
# 9 days ago
# Running
# on
# Zero
# 8.54k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# black-forest-labs
# Apr 16
# Running
# 163
# Conversational WebGPU
# 🚀
# webml-community
# 9 days ago
# Running
# on
# CPU Upgrade
# 5.84k
# MTEB Leaderboard
# 🥇
# Embedding Leaderboard
# mteb
# Apr 17
# Running
# on
# Zero
# 142
# MIDJOURNEY
# 🏜
# MidJour | A RealVisXL_Turbo | IRL HI-Res Images Gen
# Dagfinn1962
# Jan 14
# Running
# on
# CPU Upgrade
# 9.02k
# Kolors Virtual Try-On
# 👕
# Try on garments virtually using images
# Kwai-Kolors
# Sep 18, 2024
# Running
# 343
# Direct3D S2 V1.0 Demo
# 💻
# Generate 3D models with spatial sparse attention
# wushuang98
# 1 day ago
# Running
# on
# Zero
# 205
# OmniConsistency
# 🚀
# Generate styled image from reference image and external LoRA
# yiren98
# 16 days ago
# Running
# on
# L4
# 565
# OpenAudio S1
# 🏆
# Generate audio from text
# fishaudio
# 7 days ago
# Running
# on
# CPU Upgrade
# 10.4k
# AI Comic Factory
# 👩
# Create your own AI comic with a single prompt
# jbilcke-hf
# Oct 15, 2024
# Running
# on
# Zero
# 101
# SoloSpeech
# 🎯
# State-of-the-art target speech extractor
# OpenSound
# 9 days ago
# Running
# on
# Zero
# 49
# CapSpeech TTS
# 🧢
# Stylized TTS – design voice, accent, and emotion your way
# OpenSound
# 8 days ago
# Running
# 39
# Consilium MCP Server
# 🏢
# Multi-AI Expert Consensus Platform
# Agents-MCP-Hackathon
# 3 days ago
# Running
# 97
# Organization Activity Heatmap
# 🔥
# Search Hugging Face heatmaps for org activity
# cfahlgren1
# about 12 hours ago
# Previous
# 1
# 2
# 3
# ...
# 100
# Next
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# documentation page
# Webpage Title:
# Hugging Face - Documentation
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Documentations
# Hub & Client Libraries
# Hub
# Host Git-based models, datasets, and Spaces on the HF Hub
# Hub Python Library
# Python client to interact with the Hugging Face Hub
# Huggingface.js
# JavaScript libraries for Hugging Face with built-in TS types
# Tasks
# Explore demos, models, and datasets for any ML tasks
# Dataset viewer
# API for metadata, stats, and content of HF Hub datasets
# Deployment & Inference
# Inference Providers
# Call 200k+ models hosted by our 10+ Inference partners
# Inference Endpoints (dedicated)
# Deploy models on dedicated & fully managed infrastructure on HF
# Amazon SageMaker
# Train/deploy Transformers models with SageMaker/HF DLCs
# Text Generation Inference
# Serve language models with TGI optimized toolkit
# Text Embeddings Inference
# Serve embeddings models with TEI optimized toolkit
# Core ML Libraries
# Transformers
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# State-of-the-art Diffusion models in PyTorch
# Datasets
# Access & share datasets for any ML tasks
# Transformers.js
# State-of-the-art ML running directly in your browser
# Tokenizers
# Fast tokenizers optimized for research & production
# Evaluate
# Evaluate and compare models performance
# timm
# State-of-the-art vision models: layers, optimizers, and utilities
# Sentence Transformers
# Embeddings, Retrieval, and Reranking
# Training & Optimization
# PEFT
# Parameter-efficient finetuning for large language models
# Accelerate
# Train PyTorch models with multi-GPU, TPU, mixed precision
# Optimum
# Optimize HF Transformers for faster training/inference
# AWS Trainium & Inferentia
# Train/deploy Transformers/Diffusers on AWS
# TRL
# Train transformers LMs with reinforcement learning
# Safetensors
# Safe way to store/distribute neural network weights
# Bitsandbytes
# Optimize and quantize models with bitsandbytes
# Lighteval
# All-in-one toolkit to evaluate LLMs across multiple backends
# Collaboration & Extras
# Gradio
# Build ML demos and web apps with a few lines of Python
# smolagents
# Smol library to build great agents in Python
# LeRobot
# Making AI for Robotics more accessible with end-to-end learning
# AutoTrain
# AutoTrain API and UI for seamless model training
# Chat UI
# Open source chat frontend powering HuggingChat
# Leaderboards
# Create custom Leaderboards on Hugging Face
# Argilla
# Collaboration tool for building high-quality datasets
# Distilabel
# Framework for synthetic data generation and AI feedback
# Community
# Blog
# Learn
# Discord
# Forum
# Github
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Enhance Your Models in 5 Minutes with the Hugging Face Kernel Hub
# By
# drbh
# June 12, 2025
# •
# 15
# Community Articles
# view all
# Post-Training Isaac GR00T N1.5 for LeRobot SO-101 Arm
# By
# nvidia
# and 4 others
# •
# 1 day ago
# •
# 46
# The Common Pile v0.1
# By
# stellaathena
# and 2 others
# •
# 7 days ago
# •
# 38
# GRPO for GUI Grounding Done Right
# By
# HelloKKMe
# •
# 2 days ago
# •
# 25
# Announcing the Common Pile and Comma v0.1
# By
# common-pile
# •
# 7 days ago
# •
# 14
# MCP is at a Tipping Point: Here's Why You Should Care
# By
# fdaudens
# •
# 3 days ago
# •
# 14
# Open Source AI: A Cornerstone of Digital Sovereignty
# By
# frimelle
# and 1 other
# •
# 2 days ago
# •
# 12
# What if Your AI Conversations Become Public?
# By
# fdaudens
# •
# 7 days ago
# •
# 11
# Nemotron-Personas: Improve AI Training With the First Synthetic Personas Dataset Aligned to Real-World Distributions
# By
# nvidia
# and 1 other
# •
# 3 days ago
# •
# 9
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 93
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 610
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 77
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 287
# Holo1: New family of GUI automation VLMs powering GUI agent Surfer-H
# By
# Hcompany
# and 1 other
# •
# 10 days ago
# •
# 64
# Tensors
# By
# KeighBee
# •
# 6 days ago
# •
# 5
# Saying Thank You to a LLM Isn't Free — Measuring the Energy Cost of Politeness
# By
# jdelavande
# and 2 others
# •
# 1 day ago
# •
# 5
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 259
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 188
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 152
# Interactive Tools for machine learning, deep learning, and math
# By
# Suzana
# •
# 18 days ago
# •
# 44
# Build AI Apps & Super Agents with Masa Data API & Scraper Tools
# By
# MasaFoundation
# •
# 1 day ago
# •
# 4
# Featherless AI on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# June 12, 2025
# •
# 30
# Introducing Training Cluster as a Service - a new collaboration with NVIDIA
# By
# jeffboudier
# June 11, 2025
# •
# 15
# ScreenSuite - The most comprehensive evaluation suite for GUI Agents!
# By
# a-mahla
# June 6, 2025
# •
# 37
# KV Cache from scratch in nanoVLM
# By
# ariG23498
# June 4, 2025
# •
# 67
# SmolVLA: Efficient Vision-Language-Action Model trained on Lerobot Community Data
# By
# danaaubakirova
# June 3, 2025
# •
# 124
# No GPU left behind: Unlocking Efficiency with Co-located vLLM in TRL
# By
# toslali-ibm
# June 3, 2025
# guest
# •
# 48
# CodeAgents + Structure: A Better Way to Execute Actions
# By
# akseljoonas
# May 28, 2025
# •
# 52
# 🐯 Liger GRPO meets TRL
# By
# shisahni
# May 25, 2025
# guest
# •
# 40
# Dell Enterprise Hub is all you need to build AI on premises
# By
# jeffboudier
# May 23, 2025
# •
# 19
# Tiny Agents in Python: a MCP-powered agent in ~70 lines of code
# By
# celinah
# May 23, 2025
# •
# 125
# Exploring Quantization Backends in Diffusers
# By
# derekl35
# May 21, 2025
# •
# 33
# nanoVLM: The simplest repository to train your VLM in pure PyTorch
# By
# ariG23498
# May 21, 2025
# •
# 150
# Microsoft and Hugging Face expand collaboration
# By
# jeffboudier
# May 19, 2025
# •
# 21
# The Transformers Library: standardizing model definitions
# By
# lysandre
# May 15, 2025
# •
# 113
# Previous
# 1
# 2
# 3
# ...
# 42
# Next
# Community Articles
# Sort:
# 		Trending
# Post-Training Isaac GR00T N1.5 for LeRobot SO-101 Arm
# By
# nvidia
# and 4 others
# •
# 1 day ago
# •
# 46
# The Common Pile v0.1
# By
# stellaathena
# and 2 others
# •
# 7 days ago
# •
# 38
# GRPO for GUI Grounding Done Right
# By
# HelloKKMe
# •
# 2 days ago
# •
# 25
# Announcing the Common Pile and Comma v0.1
# By
# common-pile
# •
# 7 days ago
# •
# 14
# MCP is at a Tipping Point: Here's Why You Should Care
# By
# fdaudens
# •
# 3 days ago
# •
# 14
# Open Source AI: A Cornerstone of Digital Sovereignty
# By
# frimelle
# and 1 other
# •
# 2 days ago
# •
# 12
# What if Your AI Conversations Become Public?
# By
# fdaudens
# •
# 7 days ago
# •
# 11
# Nemotron-Personas: Improve AI Training With the First Synthetic Personas Dataset Aligned to Real-World Distributions
# By
# nvidia
# and 1 other
# •
# 3 days ago
# •
# 9
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 93
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 610
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 77
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 287
# Holo1: New family of GUI automation VLMs powering GUI agent Surfer-H
# By
# Hcompany
# and 1 other
# •
# 10 days ago
# •
# 64
# Tensors
# By
# KeighBee
# •
# 6 days ago
# •
# 5
# Saying Thank You to a LLM Isn't Free — Measuring the Energy Cost of Politeness
# By
# jdelavande
# and 2 others
# •
# 1 day ago
# •
# 5
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 259
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 188
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 152
# Interactive Tools for machine learning, deep learning, and math
# By
# Suzana
# •
# 18 days ago
# •
# 44
# Build AI Apps & Super Agents with Masa Data API & Scraper Tools
# By
# MasaFoundation
# •
# 1 day ago
# •
# 4
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community discussion page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Best Current voice to voice API
# Research
# 1
# 13
# June 13, 2025
# About runtime error
# Beginners
# 0
# 4
# June 13, 2025
# Replace trained ChatGPT (no coder)
# Beginners
# 1
# 10
# June 13, 2025
# Error: Provider 'featherless-ai' not supported
# Beginners
# 2
# 5
# June 13, 2025
# 401 Client Error: Unauthorized for url: https://huggingface.co/DeepBeepMeep/Wan2.1
# Beginners
# 1
# 11
# June 12, 2025
# Fast api zero GPU problem
# Beginners
# 1
# 7
# June 12, 2025
# ControlNet SDXL checkpoint
# Beginners
# 2
# 9
# June 13, 2025
# Comments on Posts get flagged?
# Beginners
# 2
# 21
# June 11, 2025
# Chainlit WebSocket Issue on Hugging Face Spaces: Missing websockets in Requirements?
# Spaces
# 4
# 91
# June 12, 2025
# Regarding the House Material Change
# Beginners
# 4
# 20
# June 13, 2025
# Unable to call google/tapas-large-finetuned-wtq model
# Beginners
# 2
# 14
# June 12, 2025
# Error 401 Client Error: Unauthorized for url
# 🤗Hub
# 65
# 102455
# June 12, 2025
# Unable to Upload arXiv Paper to HuggingFace Daily Papers
# 🤗Hub
# 2
# 19
# June 13, 2025
# Testing hugging face in langchain vs code
# Models
# 1
# 10
# June 12, 2025
# Correct way to load multiple LoRA adapters for inference
# 🤗Transformers
# 4
# 16
# June 11, 2025
# Error fine tuning Donut model using LoRA
# Beginners
# 5
# 35
# June 12, 2025
# AI House material change
# Intermediate
# 0
# 8
# June 12, 2025
# API call URL error
# Beginners
# 1
# 8
# June 12, 2025
# Text-to-Sql model keeps missing "<" token
# Intermediate
# 2
# 23
# June 11, 2025
# Just don't get it: OpenAI API in Open WebUI
# Beginners
# 2
# 11
# June 12, 2025
# HF auto train dataset load_metric error
# Beginners
# 33
# 84
# June 5, 2025
# Can I ask a question if I have a good idea but can't write programs?
# Beginners
# 41
# 258
# June 3, 2025
# Where is the link to Colab?
# Beginners
# 2
# 12
# June 12, 2025
# Triskel Data Deterministic Ai
# Beginners
# 5
# 7
# June 12, 2025
# Copyright policy regarding youtube datasets
# Intermediate
# 1
# 5
# June 12, 2025
# Hello experts please help on running local DeepSeek-R1-0528-Qwen3-8B
# Beginners
# 2
# 38
# June 10, 2025
# Workflow Forge: Open source heavy-duty workflow system
# Research
# 0
# 11
# June 12, 2025
# Built a new plot that can visualize 5–7 dimensions in 3D without losing interpretability — introducing Multi-Dimensional Radial Plot (MDRV)
# Research
# 5
# 20
# June 13, 2025
# Startup founder here — curious how you choose your cloud GPU provider?
# Beginners
# 1
# 10
# June 11, 2025
# New to hugging!
# Beginners
# 5
# 86
# June 9, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# Appearance settings
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Models
# New
# Manage and compare prompts
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Resetting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 50.1k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# Python
# 146k
# 29.3k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 29.3k
# 6k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.3k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18.8k
# 1.9k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.8k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.9k
# 546
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 321 repositories
# optimum-intel
# Public
# 🤗 Optimum Intel: Accelerate inference with Intel optimization tools
# huggingface/optimum-intel’s past year of commit activity
# Jupyter Notebook
# 469
# Apache-2.0
# 132
# 29
# 23
# Updated
# Jun 13, 2025
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# huggingface/transformers’s past year of commit activity
# Python
# 145,550
# Apache-2.0
# 29,330
# 1,050
# (2 issues need help)
# 782
# Updated
# Jun 13, 2025
# lighteval
# Public
# Lighteval is your all-in-one toolkit for evaluating LLMs across multiple backends
# Uh oh!
# There was an error while loading.
# Please reload this page
# .
# huggingface/lighteval’s past year of commit activity
# Python
# 1,621
# MIT
# 287
# 124
# (18 issues need help)
# 37
# Updated
# Jun 13, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Uh oh!
# There was an error while loading.
# Please reload this page
# .
# huggingface/diffusers’s past year of commit activity
# Python
# 29,340
# Apache-2.0
# 6,022
# 497
# (12 issues need help)
# 196
# Updated
# Jun 13, 2025
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# huggingface/optimum’s past year of commit activity
# Python
# 2,938
# Apache-2.0
# 546
# 275
# (2 issues need help)
# 44
# Updated
# Jun 13, 2025
# huggingface.js
# Public
# Utilities to use the Hugging Face Hub API
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 2,144
# MIT
# 424
# 105
# (5 issues need help)
# 57
# Updated
# Jun 13, 2025
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Uh oh!
# There was an error while loading.
# Please reload this page
# .
# huggingface/datasets’s past year of commit activity
# Python
# 20,266
# Apache-2.0
# 2,846
# 812
# (2 issues need help)
# 97
# Updated
# Jun 13, 2025
# text-embeddings-inference
# Public
# A blazing fast inference solution for text embeddings models
# Uh oh!
# There was an error while loading.
# Please reload this page
# .
# huggingface/text-embeddings-inference’s past year of commit activity
# Rust
# 3,683
# Apache-2.0
# 271
# 116
# 10
# Updated
# Jun 13, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 14,439
# Apache-2.0
# 1,843
# 248
# 153
# Updated
# Jun 13, 2025
# text-generation-inference
# Public
# Large Language Model Text Generation Inference
# huggingface/text-generation-inference’s past year of commit activity
# Python
# 10,216
# Apache-2.0
# 1,198
# 255
# 33
# Updated
# Jun 13, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 554 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 17h
# Report this post
# I have bittersweet news to share.
#
# Yesterday we merged a PR deprecating TensorFlow and Flax support in transformers.
#
# Going forward, we're focusing all our efforts on PyTorch to remove a lot of the bloating in the transformers library. Expect a simpler toolkit, across the board.
#
# This is not a decision we take lightly: multi-backend has been a big selling point of transformers over the years. However, we have seen our user base consolidate in PyTorch.
#
# We will keep support of TF and Flax with v4 as LTS (~mid 2026). This change marks the beginning of v5!
#
# We have heard the feedback about transformers being bloated with many layers of abstraction.
#
# With this, we expect to remove 50% of the code from the library. This will contribute to removing abstraction layers; aligned with our focus on simplification:
# https://lnkd.in/eRMMj_fm
# If you're still interested in running in Jax/TF/Keras, stay tuned, we're working with tools like MaxText/MaxDiffusion/Keras 3 to see how to use the transformers model definitions.
#
# We'll aim to continue having maximum compatibility with that ecosystem, even if outside of PyTorch.
# 846
# 29 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗
# 1d
# Report this post
# So many models released past week in open AI, here’s the weekly picks 🥹
# You can find more models, datasets and demos in the link in comments 💬
#
# 📚 LLMs/Retrieval
# > Qwen released Qwen3-Reranker-4B, a text retriever that it supports 100+ languages ranking #1 on MTEB!
# > Qwen also released Qwen3-Embedding models, new embeddings that come In 600M, 4B & 8B
# > Openbmb released MiniCPM4, new family of efficient LLMs that come in different sizes for end-side devices (OS) they also released an MCP compatible version
# > Homunculus is a 12B hybrid (reasoning/chat) model distilled from Qwen3-235B by Arcee AI (OS)
#
# 🖼️💬 VLMs
# > MonkeyOCR is a new open-source state-of-the-art 3B document parser (OS)
# > Google DeepMind released desktop version of Gemma 3n
# > NVIDIA released Llama-3.1-Nemotron-Nano-VL-8B-V1, new VLM
# > MSFT released an agentic VLM for GUI control GUI-Actor-7B-Qwen2-VL based on Qwen2-VL-7B (OS)
#
# 🤖 VLAs/Robotics
# > RoboBrain2.0-7B is a new VLA with action planning with 7B and 32B sizes (OS)
# > Hugging Face released SmolVLA-Base, new vision language action model (OS)
#
# 🗣️ Audio
# > openaudio-s1-mini is a new text-to-speech model with support for various languages, offers emotional and tone markers by fishaudio
#
# ⏯️ Video Gen
# > ByteDance released ContentV-8B, new video generation model for portraits, scenes, unusual setups and more! (OS)
#
# Which one is your favorite? 👀
# …more
# 137
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 20h
# Report this post
# Brand new MCP Course has units are out, and now it's getting REAL! We've collaborated with Anthropic to dive deep into production ready and autonomous agents using MCP
#
# 🔗
# https://lnkd.in/eTuSr-Uh
# This is what the new material covers and includes:
#
# - Use Claude Code to build an autonomous PR agent
# - Integrate your agent with Slack and Github to integrate it with you Team
# - Get certified on your use case and share with the community
# - Build an autonomous PR cleanup agent on the Hugging Face hub and deploy it with spaces
#
# The material goes deep into these problems and helps you to build applications that work. We’re super excited to see what you build with it.
# 666
# 15 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Aymeric Roucher
# Leading agents @ Hugging Face 🤗 | Polytechnique - Cambridge
# 1d
# Edited
# Report this post
# Almost didn't take time to celebrate : Smolagents just wooshed past 20k stars on Github! ⭐️
#
# Congrats to the team, especially
# Albert Villanova
# who spends lots of time improving the library, and to our community members who keep pushing it to the edge 👏
#
# It's still time to learn to use agents, head to our doc or the Agents course to get started!
# View C2PA information
# 90
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# 988,378 followers
# 1d
# Report this post
# Check out the latest VJEPA 2 - SoTA world models from
# AI at Meta
# 🔥
#
# It was a pleasure collaborating with them to bring these models readily available in transformers! 🤗
# AI at Meta
# 968,361 followers
# 1d
# We’re sharing V-JEPA 2, a new world model with state-of-the-art performance in visual understanding and prediction.
#
# V-JEPA 2 is a 1.2 billion-parameter model, trained on video, that can enable zero-shot planning in robots—allowing them to plan and execute tasks in unfamiliar environments.
#
# Learn more about V-JEPA 2 ➡️
# https://lnkd.in/gNgpzpvu
# As we continue working toward our goal of achieving advanced machine intelligence (AMI), we’re also releasing three new benchmarks for evaluating how well existing models can reason about the physical world from video.
#
# Learn more and download the new benchmarks ➡️
# https://lnkd.in/gNgpzpvu
# 90
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 1d
# Report this post
# Super excited to release AutoTrain-MCP! This is an MCP server for training AI models, so you can use your AI tools to train your AI models 🤯.
#
# 🔗
# https://lnkd.in/dUuarxBP
# Use this MCP server with tools like Claude Desktop, Cursor, VSCode, ChatGPT, or Continue to do this:
#
# - Define an ML problem like Image Classification, LLM fine-tuning, Text Classification, etc.
# - Claude Desktop etc. can retrieve models and datasets from the hub using the hub MCP.
# - Training happens on a Hugging Face space, so no worries about hardware restraints.
# - Models are pushed to the hub to be used inference tools like
# Llama.cpp
# , vLLM, MLX, etc.
# - Built on top of the AutoTrain library, so it has full integration with transformers and other libraries.
#
# Everything is still under active development, but I’m super excited to hear what people build, and I’m open to contributions!
# 418
# 20 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 3d
# Report this post
# Bitsandbytes (BnB) is a popular quantization framework in the community. Did you know that its latest version works with `torch.compile()` WITHOUT introducing graph breaks? 🤯
#
# This means when a  BnB-quantized model is compiled with `fullgraph=True`, it's expected to observe good speedups.
#
# I applied this to Flux, and no wonder, it beefs up the performance quite a bit 🤏 Hugo kudos to
# Matthew Douglas
# and team for shipping this!
#
# Even better is that it can be combined with group offloading to provide you with a nice trade-off between speed and memory, even on resource-constrained hardware 🔥
#
# What is your favorite optimization combo?
# 150
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Aymeric Roucher
# Leading agents @ Hugging Face 🤗 | Polytechnique - Cambridge
# 2d
# Report this post
# Thrilled to announce that world-leading venture firm
# Accel
# is joining our Agents Hack next Sunday ! 🔥
#
# They're joining forces with us (
# Hugging Face
# ),
# Anthropic
# and
# Unaite
# to organize the biggest ever hackathon on Agents in Paris, with over 10k€ in prizes, including large cash prizes for the top 3 teams.
#
# Thank you
# Rafael Quintanilla Loeillet
# and
# Sam Fold
# for your support!
#
# 📅 This Sunday, June 15th
# 🚨 We just opened 20 more slots for grabs, apply here 👉
# https://lu.ma/qpimrbx3
# 36
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 2d
# Edited
# Report this post
# Introducing
# Hugging Face
# Sheets: Excel meets AI and unstructured data 👇
#
#
# 📁  Effortlessly run prompts and models over your data.
# 🌐   Agentic search for accuracy and real-time information.
# 🖼️  Familiar, minimalistic interface for interacting with data.
# 🎯  Human feedback 2.0: Your input directly improves generated data.
# 💯 Use hundreds of open models and leading inference providers.
#
#
# Try it out and share it with your loved ones, it's free!
# https://lnkd.in/dVu2f2SB
# (Put your sound ON 🔊 )
# …more
# 718
# 36 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,760 followers
# 2d
# Report this post
# 🚨 400+ submissions and counting!
#
# Today’s the LAST day to submit for the biggest-ever Agents & MCP Hackathon.
#
# $16,500 in cash prizes
#
# Let’s goooo 👉
# https://lnkd.in/g7yp9HKG
# 39
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company in a super creative and fun manner for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussion', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nmistralai/Magistral-Small-2506\nUpdated\n2 days ago\n•\n5.82k\n•\n362\nopenbmb/MiniCPM4-8B\nUpdated\nabout 8 hours ago\n•\n3.06k\n•\n217\nQwen/Qwen3-Embedding-0.6B-GGUF\nUpdated\n4 days ago\n•\n14.8k\n•\n345\ndeepseek-ai/DeepSeek-R1-0528\nUpdated\n15 days ago\n•\n116k\n•\n1.95k\nfishaudio/openaudio-s1-mini\nUpdated\n10 days ago\n•\n2.38k\n•\n251\nBrowse 1M+ models\nSpaces\nRunning\n7.99k\n7.99k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n1.04k\n1.04k\nChatterbox TTS\n🍿\nExpressive Zeroshot TTS\nRunning\non\nZero\n669\n669\nWan2.1 Fast\n🎥\nTurn static images into animated videos\nRunning\n153\n153\nSheets\n🗂\nConvert ideas into structured datasets\nRunning\n537\n537\nRealistic Text To Speech Unlimited\n🔥\nFree Text-To-Speech generator with Emotion control (OpenAI)\nBrowse 400k+ applications\nDatasets\nnvidia/Nemotron-Personas\nUpdated\n4 days ago\n•\n4.12k\n•\n76\nopen-thoughts/OpenThoughts3-1.2M\nUpdated\n4 days ago\n•\n11k\n•\n99\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n22.5k\n•\n7.91k\na-m-team/AM-DeepSeek-R1-0528-Distilled\nUpdated\n4 days ago\n•\n4.83k\n•\n64\ninstitutional/institutional-books-1.0\nUpdated\n1 day ago\n•\n423\n•\n27\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n765 models\n•\n3.42k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.16k models\n•\n6.41k followers\nAmazon\ncompany\n•\n20 models\n•\n3.23k followers\nGoogle\ncompany\n•\n999 models\n•\n16.5k followers\nIntel\ncompany\n•\n232 models\n•\n2.63k followers\nMicrosoft\ncompany\n•\n390 models\n•\n12.9k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n162 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n297 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n145,550\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,340\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,304\nSafe way to store/distribute neural network weights\nHub Python Library\n2,682\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,793\nFast tokenizers optimized for research & production\nTRL\n14,157\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,796\nState-of-the-art ML running directly in your browser\nsmolagents\n20,093\nSmol library to build great agents in Python\nPEFT\n18,756\nParameter-efficient finetuning for large language models\nDatasets\n20,266\nAccess & ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'social media page', 'url': 'https://twitter.com/huggingface'}, {'type': 'social media page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# ```markdown
# # 🌻 Welcome to Hugging Face! 🌻
#
# ## The AI Community Building the Future
#
# At Hugging Face, we’re not just creating machine learning models; we’re brewing a **community of innovators**, makers, and dreamers. Our mission is simple: to make the world of artificial intelligence accessible to everyone! 🌍💡
#
# ### 🎉 Why Choose Hugging Face?
#
# - **Collaboration**: Connect with fellow AI enthusiasts! Work on models, datasets, and applications collaboratively for smarter, faster results. 🤝
#
# - **Holistic AI Solution**: With over **1 million models** and **250k+ datasets**, you can find exactly what you need in a heartbeat. 🌟
#
# - **Spaces to Innovate**: Run dynamic applications and explore the world of AI with our dedicated Spaces—perfect for prototyping and sharing your projects. 🛠️
#
# ### 🚀 Hugging Face Highlights:
#
# - **_models_**: Dive into the latest and trending models, from text to video and everything in between! 📈
# - **_datasets_**: Access a vibrant collection of datasets for every project!
# - **_enterprise solutions_**: From individual creators to large enterprises, we’ve got all you need to accelerate your journey in machine learning. 🚀
#
# ### 🚀 Join the Revolution
#
# **Become a part of something big!** With more than **50,000 organizations** using Hugging Face — including giants like *Google*, *Amazon*, *Microsoft*, and various exciting startups — you’ll be in great company! 🏢✨
#
# ### 👐 Our Culture
#
# At Hugging Face, **we believe in transparency**, **inclusivity**, and the **power of collaboration**. We foster a growth-oriented culture where every idea counts, and creativity flows freely. Join us, and you’ll find yourself in an environment that nurtures innovation while empowering individuals to share their unique perspectives! 🌈💪
#
# ### 🌈 Careers at Hugging Face
#
# Looking for your next adventure? **Join our team!** We’re constantly on the lookout for passionate, creative minds to help us reshape the future of AI. Check out our [Careers page](#) to find open positions, from AI developers to community managers. 🧑‍💻🚀
#
# ### 🌟 Let’s Connect!
#
# Whether you’re a curious novice, a seasoned expert, or an investor looking to delve into the world of AI, there is a place for you at Hugging Face!
#
# **Explore** our cutting-edge tools, **join** our vibrant community, or **build** your next AI model with us today!
#
# 🌐 **Find us at:** [Hugging Face](https://huggingface.co)
# 📧 **Contact us:** info@huggingface.co
# 💼 **Follow us:** [Twitter](https://twitter.com/huggingface) | [LinkedIn](https://www.linkedin.com/company/huggingface/) | [Discord](https://discord.gg/huggingface)
#
# Together, let’s build the future! 💫
# ```

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation', 'url': 'https://huggingface.co/docs'}]}
# # Welcome to Hugging Face! 🤗
#
# **The AI Community Building the Future!**
#
# ---
#
# ### Who We Are
#
# At **Hugging Face**, we are more than just a tech company - we're a thriving community at the forefront of **AI** and **machine learning (ML)** innovation! With over **1 million models** and countless datasets at your fingertips, we provide an open platform for collaboration and creativity, empowering everyone from developers to researchers to bring their AI visions to life!
#
# ---
#
# ### Our Offerings
#
# 1. **Models**: Browse and discover over 1 million ML models to kickstart your projects.
#
# 2. **Datasets**: Access 250k+ datasets tailored for various ML tasks.
#
# 3. **Spaces**: Deploy applications and showcase your creativity! Create engaging applications effortlessly.
#
# 4. **Enterprise Solutions**: Custom-tailored services that include dedicated support, security, and optimized resources, with pricing starting at just **$20/user/month**.
#
# ---
#
# ### Community Spirit 🤝
#
# Join a collective of **over 50,000 organizations** including industry giants like AI2, Meta, Amazon, and Google! Our open-source community encourages developers, researchers, and hobbyists to collaborate and innovate, sharing their models and applications on our easy-to-navigate platform.
#
# - **Follow community trends**: From the latest model updates to trending applications, never miss out on what’s hot in AI!
#
# - **Community Engagement**: Join discussions, participate in forums, and contribute to projects you’re passionate about.
#
# ---
#
# ### Work Culture at Hugging Face 🌟
#
# We foster a **collaborative**, **inclusive**, and **innovative** environment. Our team is made up of bright minds from various fields, and we believe in the importance of diverse perspectives to fuel creativity and drive progress. Join us to be a part of a team that values **open-source collaboration** and **continuous learning**!
#
# ---
#
# ### Join Us! 🚀
#
# Looking for a **career** that lets you explore AI's potential? Here at Hugging Face, we are always on the lookout for passionate individuals. Explore open positions and shape the future of AI with us!
#
# - 💼 [Check out our job openings](https://huggingface.co/jobs)
#
# ---
#
# ### Ready to Explore? ⚡
#
# Discover the limitless possibilities with **Hugging Face** and become a part of the AI revolution today!
#
# - **Explore AI Apps**: See what's trending in real-time!
# - **Sign Up**: Create your account and join the conversation!
#
# 🔗 **Website**: [huggingface.co](https://huggingface.co)
#
# ---
#
# Let’s build the future together! **Join the Hugging Face community today!** 🤗

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
